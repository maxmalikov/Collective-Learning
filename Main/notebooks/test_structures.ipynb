# %% [markdown]
# # Test the different kinds of structures

# %%
import sys
sys.path.append("./Main/src")

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from models_cl import CollectiveLearningModel

# %% [markdown]
# ### Consensus

# %%
scenario = "consensus"

model = CollectiveLearningModel(
    n_agents=10,
    n_choices=6,
    network_type=scenario,
    alignment_max_time=1,
    consensus_threshold=1.0,
)
model.draw_network()
# Out:
# <Axes: title={'center': '10 agents, 45 ties'}>

# %% [markdown]
# ### Consultative

# %%
scenario = "consultative"

model = CollectiveLearningModel(
    n_agents=10,
    n_choices=6,
    network_type=scenario,
    alignment_max_time=1,
    consensus_threshold=1.0,
)
model.draw_network()
# Out:
# <Axes: title={'center': '11 agents, 10 ties'}>

# %% [markdown]
# ### Leader

# %%
scenario = "autocratic"

model = CollectiveLearningModel(
    n_agents=10,
    n_choices=6,
    network_type=scenario,
    alignment_max_time=1,
    consensus_threshold=1.0,
)
model.draw_network()
# Out:
# <Axes: title={'center': '11 agents, 10 ties'}>
